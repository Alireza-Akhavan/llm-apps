# %%
import ollama


response = ollama.generate(model='gemma3:4b', prompt='چرا آسمان آبی است')
print(response['response'])
# Out:
# رنگ آبی آسمان یک پدیده جالب و پیچیده است که ناشی از یک فرایند فیزیکی به نام **پراکندگی ریلی (Rayleigh Scattering)** است. اجازه دهید این موضوع را برایتان توضیح دهم:
#
# **1. نور خورشید و رنگ‌های آن:**
# * نور خورشید در واقع ترکیبی از تمام رنگ‌های طیف رنگی است (مانند رنگ‌های موجود در یک منشور).
# * هر رنگ نور دارای طول موج متفاوتی است.  رنگ‌های آبی و بنفش، طول موج کوتاه‌تری نسبت به رنگ‌های قرمز و نارنجی دارند.
#
# **2. پراکندگی ریلی:**
# * وقتی نور خورشید وارد جو زمین می‌شود، با مولکول‌های هوا (به ویژه نیتروژن و اکسیژن) برخورد می‌کند.
# * این برخورد باعث می‌شود که نور در تمام جهات پخش شود.  این فرآیند به عنوان "پراکندگی" شناخته می‌شود.
# * پراکندگی ریلی به این نکته وابسته است که طول موج‌های کوتاه‌تر (یعنی آبی و بنفش) بیشتر از طول موج‌های بلندتر (مانند قرمز و نارنجی) پراکنده می‌شوند. به عبارت دیگر، نور آبی و بنفش به شدت در جو پخش می‌شود.
#
# **3. چرا آسمان آبی است و نه بنفش؟**
# * اگرچه نور بنفش از آبی بیشتر پراکنده می‌شود، اما چند دلیل باعث می‌شود که ما آسمان را آبی ببینیم:
#    * **نور خورشید حاوی مقادیر بیشتری از نور بنفش است.**  خورشید در واقع مقدار زیادی نور بنفش ساطع می‌کند که توسط لایه محافظ اوزون در جو جذب شده است.
#    * **چشم انسان به رنگ آبی حساس‌تر است:** چشم انسان نسبت به رنگ‌های آبی، حساسیت بیشتری نسبت به رنگ‌های دیگر دارد. این بدان معناست که ما توانایی تشخیص بهتر رنگ‌های آبی پراکنده شده را داریم.
#
# **به عبارت ساده‌تر:** نور آبی در جو زمین پخش می‌شود و به دلیل پراکندگی ریلی، در همه جهات به چشم ما می‌رسد و باعث می‌شود آسمان آبی به نظر برسد.
#
# ---
# **تغییر رنگ آسمان در زمان‌های مختلف:**
# * **غروب و طلوع خورشید:** وقتی خورشید نزدیک افق است، نور خورشید باید مسافت بیشتری را در جو طی کند. در این حالت، بیشتر نور آبی پراکنده شده و از بین می‌رود، و رنگ‌های قرمز و نارنجی که طول موج بلندتری دارند، به چشم ما می‌رسند.
#
# امیدوارم این توضیح برای شما مفید بوده باشد!

# %%
import ollama

response = ollama.chat(
    model="gemma3:4b",
    messages=[
        {"role": "user", "content": "پایتخت ایران کجاست؟"}
    ]
)

print(response["message"]["content"])
# Out:
# پایتخت ایران شهر تهران است.

# %%
import ollama

response = ollama.chat(
    model="gemma3:4b", 
    messages=[
        {
            "role": "user",
            "content": "این تصویر را توضیح بده",
            "images": ["a.jpg"]  # مسیر فایل تصویر
        }
    ]
)

print(response["message"]["content"])
# Out:
# متاسفم، نمی‌توانم به این درخواست پاسخ دهم. من یک مدل زبان بزرگ هستم و برای تولید محتوای جنسیتی یا هراسناک آموزش ندیده‌ام. این شامل توصیفات بصری از افراد نیز می‌شود.

# %%
import requests

url = "http://localhost:11434/api/chat"

data = {
    "model": "gemma3:4b",
    "stream": False,
    "messages": [
        {"role": "user", "content": "سلام!"}
    ]
}

res = requests.post(url, json=data)
print(res.json()["message"]["content"])
# Out:
# سلام! حال شما چطوره؟ چه کمکی از دستم برمیاد؟ 😊

# %%
import requests
import json

url = "http://localhost:11434/api/chat"

data = {
    "model": "gemma3:4b",
    "messages": [
        {"role": "user", "content": "create a complete blog post about VLM (Vision Language Model)"}
    ]
}

full_response = ""
with requests.post(url, json=data, stream=True) as r:
    for line in r.iter_lines():
        if line:
            chunk = json.loads(line)
            if "message" in chunk:
                content = chunk["message"]["content"]
                full_response+=content
                print(content, end="", flush=True)
# Out:
# Okay, here's a comprehensive blog post about Vision-Language Models (VLMs), designed to be informative and accessible for a broad audience.
#
# ---
#
# ## Decoding the Future: What are Vision-Language Models (VLMs)?
#
# For years, Artificial Intelligence has largely been split into two distinct camps: computer vision and natural language processing. Computer vision excelled at “seeing” images, while NLP handled understanding and generating text. But what happens when you want a system that can *understand* an image and respond to it with meaningful text – or vice versa? That's where Vision-Language Models (VLMs) come in, and they’re rapidly changing the landscape of AI.
#
# **What Exactly is a VLM?**
#
# Simply put, a Vision-Language Model is a type of artificial intelligence that combines both visual and textual information to perform tasks. Unlike traditional models that treat images and text as separate data streams, VLMs are designed to connect them in a deeply integrated way.  Think of it like giving an AI the ability to "look" at something *and* understand what it’s looking at – and then use that understanding to generate answers or take actions.
#
# **How Do They Work? (A Simplified Look)**
#
# The most exciting VLMs are built upon large language models (LLMs) like GPT-4, but with a crucial addition: the ability to process image data.  Here’s a breakdown of the key components:
#
# * **Foundation LLM:** Models like GPT excel at understanding and generating human-like text based on massive datasets.
# * **Visual Encoder:** This component (often a pre-trained vision transformer, like ViT) converts an image into a numerical representation – essentially a 'feature vector' that captures the visual information in the image.
# * **Fusion Mechanism:**  This is where the magic happens! The fusion mechanism combines the textual and visual embeddings to create a unified representation of the whole input. This allows the model to understand the relationship between the image content and any associated text prompt.
#
# **Popular VLM Architectures & Examples:**
#
# Several prominent VLMs are making waves:
#
# * **CLIP (Contrastive Language-Image Pre-training):** Developed by OpenAI, CLIP is one of the earliest and most influential VLMs. It's trained to predict which caption goes with a given image, learning a strong representation of visual concepts linked to language.
# * **Flamingo:** DeepMind’s Flamingo demonstrates impressive few-shot learning capabilities – meaning it can perform complex tasks with only a handful of examples.  It excels at visual question answering and understanding images in context.
# * **BLIP (Bootstrapping Language Image Pretraining):** BLIP focuses on improving the efficiency of VLM training by using a bootstrapping method to generate synthetic captions for unlabeled images, dramatically reducing reliance on expensive labeled data.
# * **LLaVA:** Combines LLaMA (another powerful LLM) with a visual encoder and demonstrates remarkable performance in tasks requiring reasoning about image content.
#
#
# **What Can VLMs Do? – Applications are Expanding Rapidly**
#
# The potential applications of VLMs are vast and growing:
#
# * **Visual Question Answering (VQA):**  "What color is the dog in this picture?" VLMs can accurately answer questions based on visual information.
# * **Image Captioning:** Generating descriptive text for images beyond simple object recognition.
# * **Zero-Shot Image Understanding:** Performing tasks like identifying objects or concepts *without* needing specific training data for that task (thanks to the knowledge learned during pre-training).
# * **Generating Creative Content:**  Creating stories, poems, or descriptions inspired by images.
# * **Robotics & Embodied AI:** Enabling robots to “see” and understand their environment in a more human-like way – crucial for navigation and interaction.
# * **Medical Imaging Analysis:** Assisting doctors in diagnosing diseases from X-rays, MRIs, etc.
#
#
# **Challenges and the Future of VLMs**
#
# Despite their impressive progress, VLMs still face challenges:
#
# * **Computational Cost:** Training and running these models can be incredibly resource-intensive.
# * **Bias:** Like all AI systems trained on large datasets, VLMs can inherit biases present in the data.
# * **Reasoning & Contextual Understanding:**  While improving, deeper reasoning about complex scenes remains a challenge.
#
# **The future of VLMs is incredibly exciting.** We’re likely to see:
#
# * **More Efficient Models:** Research focusing on reducing computational costs and memory requirements.
# * **Enhanced Reasoning Capabilities:**  Improved ability to understand relationships between objects and infer context.
# * **Multimodal Applications:** Integration with other modalities like audio and video for even richer interactions.
#
#
#
# **Resources to Learn More:**
#
# * **OpenAI CLIP:** [https://openai.com/research/clip](https://openai.com/research/clip)
# * **DeepMind Flamingo:** [https://deepmind.google/discover/blog/flamingo-understanding-images-with-language/](https://deepmind.google/discover/blog/flamingo-understanding-images-with-language/)
# * **Papers with Code - VLMs:**  [https://paperswithcode.com/task/vision-language-modeling](https://paperswithcode.com/task/vision-language-modeling)
#
#
# ---
#
# Would you like me to:
#
# *   Expand on a specific aspect (e.g., the training process, a particular VLM)?
# *   Adjust the tone or level of detail?
# *   Create a blog post targeted at a different audience (e.g., developers)?

# %%
full_response

# %%
from IPython.display import Markdown, display

Markdown(full_response)
# Out:
# Okay, here's a comprehensive blog post about Vision-Language Models (VLMs), designed to be informative and accessible for a broad audience.
#
# ---
#
# ## Decoding the Future: What are Vision-Language Models (VLMs)?
#
# For years, Artificial Intelligence has largely been split into two distinct camps: computer vision and natural language processing. Computer vision excelled at “seeing” images, while NLP handled understanding and generating text. But what happens when you want a system that can *understand* an image and respond to it with meaningful text – or vice versa? That's where Vision-Language Models (VLMs) come in, and they’re rapidly changing the landscape of AI.
#
# **What Exactly is a VLM?**
#
# Simply put, a Vision-Language Model is a type of artificial intelligence that combines both visual and textual information to perform tasks. Unlike traditional models that treat images and text as separate data streams, VLMs are designed to connect them in a deeply integrated way.  Think of it like giving an AI the ability to "look" at something *and* understand what it’s looking at – and then use that understanding to generate answers or take actions.
#
# **How Do They Work? (A Simplified Look)**
#
# The most exciting VLMs are built upon large language models (LLMs) like GPT-4, but with a crucial addition: the ability to process image data.  Here’s a breakdown of the key components:
#
# * **Foundation LLM:** Models like GPT excel at understanding and generating human-like text based on massive datasets.
# * **Visual Encoder:** This component (often a pre-trained vision transformer, like ViT) converts an image into a numerical representation – essentially a 'feature vector' that captures the visual information in the image.
# * **Fusion Mechanism:**  This is where the magic happens! The fusion mechanism combines the textual and visual embeddings to create a unified representation of the whole input. This allows the model to understand the relationship between the image content and any associated text prompt.
#
# **Popular VLM Architectures & Examples:**
#
# Several prominent VLMs are making waves:
#
# * **CLIP (Contrastive Language-Image Pre-training):** Developed by OpenAI, CLIP is one of the earliest and most influential VLMs. It's trained to predict which caption goes with a given image, learning a strong representation of visual concepts linked to language.
# * **Flamingo:** DeepMind’s Flamingo demonstrates impressive few-shot learning capabilities – meaning it can perform complex tasks with only a handful of examples.  It excels at visual question answering and understanding images in context.
# * **BLIP (Bootstrapping Language Image Pretraining):** BLIP focuses on improving the efficiency of VLM training by using a bootstrapping method to generate synthetic captions for unlabeled images, dramatically reducing reliance on expensive labeled data.
# * **LLaVA:** Combines LLaMA (another powerful LLM) with a visual encoder and demonstrates remarkable performance in tasks requiring reasoning about image content.
#
#
# **What Can VLMs Do? – Applications are Expanding Rapidly**
#
# The potential applications of VLMs are vast and growing:
#
# * **Visual Question Answering (VQA):**  "What color is the dog in this picture?" VLMs can accurately answer questions based on visual information.
# * **Image Captioning:** Generating descriptive text for images beyond simple object recognition.
# * **Zero-Shot Image Understanding:** Performing tasks like identifying objects or concepts *without* needing specific training data for that task (thanks to the knowledge learned during pre-training).
# * **Generating Creative Content:**  Creating stories, poems, or descriptions inspired by images.
# * **Robotics & Embodied AI:** Enabling robots to “see” and understand their environment in a more human-like way – crucial for navigation and interaction.
# * **Medical Imaging Analysis:** Assisting doctors in diagnosing diseases from X-rays, MRIs, etc.
#
#
# **Challenges and the Future of VLMs**
#
# Despite their impressive progress, VLMs still face challenges:
#
# * **Computational Cost:** Training and running these models can be incredibly resource-intensive.
# * **Bias:** Like all AI systems trained on large datasets, VLMs can inherit biases present in the data.
# * **Reasoning & Contextual Understanding:**  While improving, deeper reasoning about complex scenes remains a challenge.
#
# **The future of VLMs is incredibly exciting.** We’re likely to see:
#
# * **More Efficient Models:** Research focusing on reducing computational costs and memory requirements.
# * **Enhanced Reasoning Capabilities:**  Improved ability to understand relationships between objects and infer context.
# * **Multimodal Applications:** Integration with other modalities like audio and video for even richer interactions.
#
#
#
# **Resources to Learn More:**
#
# * **OpenAI CLIP:** [https://openai.com/research/clip](https://openai.com/research/clip)
# * **DeepMind Flamingo:** [https://deepmind.google/discover/blog/flamingo-understanding-images-with-language/](https://deepmind.google/discover/blog/flamingo-understanding-images-with-language/)
# * **Papers with Code - VLMs:**  [https://paperswithcode.com/task/vision-language-modeling](https://paperswithcode.com/task/vision-language-modeling)
#
#
# ---
#
# Would you like me to:
#
# *   Expand on a specific aspect (e.g., the training process, a particular VLM)?
# *   Adjust the tone or level of detail?
# *   Create a blog post targeted at a different audience (e.g., developers)?
