# %% [markdown]
# ## Installing LiteLLM Package
#
# To use LiteLLM, you need to install it first. The installation method depends on your internet access:
#
# ### 🌐 Open Internet (No Restrictions)
#
# ```
# pip install litellm
# ```
#
# ### 🇮🇷 Iran Local Network (Restricted access to PyPI)
#
# Use the internal mirror:
#
# ```
# pip install -i https://mirror-pypi.runflare.com/simple litellm
#
# ```

# %%
from litellm import completion
from dotenv import load_dotenv

# %% [markdown]
# ## Load Environment Variables
#
# Load your `.env` file which contains environment variables such as `OPENAI_API_KEY`, `OLLAMA_API_BASE`, etc.:

# %%
load_dotenv()
# Out:
# True

# %%
response = completion(
    model="ollama/gemma3:4b",
    messages=[{"role": "user", "content": "سلام"}]
)

# %%
print(response)
# Out:
# ModelResponse(id='chatcmpl-04e4b18b-24aa-4d82-a079-f464d8eb487f', created=1787988617, model='ollama/gemma3:4b', object='chat.completion', system_fingerprint=None, choices=[Choices(finish_reason='stop', index=0, message=Message(content='سلام! چطور میتونم کمکت کنم؟ 😊\n', role='assistant', tool_calls=None, function_call=None, provider_specific_fields=None, reasoning_content=None))], usage=Usage(completion_tokens=14, prompt_tokens=16, total_tokens=30, completion_tokens_details=None, prompt_tokens_details=None))

# %%
import json
print(json.dumps(response.model_dump(), indent=2, ensure_ascii=False))
# Out:
# {
#   "id": "chatcmpl-04e4b18b-24aa-4d82-a079-f464d8eb487f",
#   "created": 1787988617,
#   "model": "ollama/gemma3:4b",
#   "object": "chat.completion",
#   "system_fingerprint": null,
#   "choices": [
#     {
#       "finish_reason": "stop",
#       "index": 0,
#       "message": {
#         "content": "سلام! چطور میتونم کمکت کنم؟ 😊\n",
#         "role": "assistant",
#         "tool_calls": null,
#         "function_call": null,
#         "reasoning_content": null
#       }
#     }
#   ],
#   "usage": {
#     "completion_tokens": 14,
#     "prompt_tokens": 16,
#     "total_tokens": 30,
#     "completion_tokens_details": null,
#     "prompt_tokens_details": null
#   }
# }

# %%
print(response['choices'][0]['message']['content'])
# Out:
# سلام! چطور میتونم کمکت کنم؟ 😊

# %%
prompt ="پایتخت ایران کجاست؟"

response = completion(
    model="ollama/gemma3:4b",
    messages=[{"role": "user", "content": prompt}]
)
print(response['choices'][0]['message']['content'])
# Out:
# تهران

# %%
from IPython.display import display, Markdown

text = response['choices'][0]['message']['content']
display(Markdown(text))
# Out:
# تهران

# %%
prompt = "یک پاراگراف در مورد ایران بنویس"

response = completion(
    model="ollama/gemma3:4b",
    messages=[{"role": "user", "content": prompt}],
    stream=True  # فعال کردن استریم
)

# چاپ استریمی
for chunk in response:
    if chunk['choices'][0].get('delta', {}).get('content'):
        print(chunk['choices'][0]['delta']['content'], end='', flush=True)
# Out:
# ایران، کشوری باستانی و غنی در قلب خاورمیانه، از جمله مهم‌ترین مراکز تمدن‌های پیشین مانند ماد، آشور و هخامنشی بوده است. این کشور به دلیل تاریخچه طولانی، فرهنگ منحصربه‌فرد و جاذبه‌های گردشگری فراوانش، از جمله تخت‌جمشید، میدان نقش جهان اصفهان و مجموعه عالی قاجار، مورد توجه جهانیان قرار گرفته است. ایران دارای منابع طبیعی قابل توجهی مانند نفت و گاز است و به عنوان یک کشور با جمعیت حدود ۸۷ میلیون نفر یکی از بزرگ‌ترین اقتصادهای منطقه محسوب می‌شود. همچنین، موسیقی سنتی، هنر خوشنویسی و صنایع دستی ایرانی، میراث ارزشمند فرهنگی این ملت را نشان می‌دهند.

# %% [markdown]
# ## Unified Interface with LiteLLM: Same Code, Different Providers (Ollama vs OpenAI)

# %%
prompt ="تو کی هستی؟"

response = completion(
    model="ollama/llama3.1:8b",
    messages=[{"role": "user", "content": prompt}]
)
print(response['choices'][0]['message']['content'])
# Out:
# من یک برنامه ی هوشمند می‌مونم. می توانم اطلاعات مختلف از جمله تاریخچه، جغرافیا و فرهنگ را برایتان فراهم کنم. اگر به موضوع خاصی در مورد آن سوال دارید می‌توانستم به شما جواب دادم.
#
# درباره خود من بیشتر می‌خواهید بدانید؟

# %%
prompt ="تو کی هستی؟"

response = completion(
    model="ollama/gemma3:4b",
    messages=[{"role": "user", "content": prompt}]
)
print(response['choices'][0]['message']['content'])
# Out:
# من یک مدل زبان بزرگ هستم که توسط گوگل توسعه داده شده‌ام.
#
# به بیان ساده، من یک برنامه کامپیوتری هستم که آموزش دیده است تا متون و کدهای انسانی تولید کند. می‌توانم به سوالات شما پاسخ دهم، متن بنویسم، ترجمه کنم، کد تولید کنم و بسیار بیشتر.

# %%
prompt ="تو کی هستی؟"

response = completion(
    model="openai/gpt-5.2",
    messages=[{"role": "user", "content": prompt}]
)
print(response['choices'][0]['message']['content'])
# Out:
# من یک دستیار هوش مصنوعی هستم (ChatGPT) که توسط OpenAI ساخته شده‌ام. می‌تونم به سؤال‌ها جواب بدم، توضیح بدم، ترجمه کنم، متن بنویسم، ایده پیشنهاد کنم و در کارهای مختلف کمک کنم.
#
# اگر بگی دقیقاً برای چی می‌خوای (مثلاً درس، برنامه‌نویسی، نوشتن، یا مشاوره‌ی عمومی)، بهتر راهنمایی‌ات می‌کنم.

# %%
prompt ="تو کی هستی؟"

response = completion(
    model="openai/claude-sonnet-4-6",
    messages=[{"role": "user", "content": prompt}]
)
print(response['choices'][0]['message']['content'])
# Out:
# من یک دستیار هوش مصنوعی هستم که توسط **Anthropic** ساخته شده‌ام و نامم **Claude** است.
#
# می‌توانم در موارد مختلفی مثل:
# - پاسخ به سوالات
# - نوشتن و ویرایش متن
# - تحلیل و بررسی موضوعات
# - مکالمه و گفتگو
#
# کمکت کنم. 😊
#
# چطور می‌تونم کمکت کنم؟

# %% [markdown]
# ## Image Analysis with LiteLLM (Vision Support)

# %%
from litellm import completion
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_path = "image.webp"
base64_image = encode_image(image_path)

response = completion(
    model="openai/gpt-4o",  # or "ollama/llava" or ... for local vision model
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "یه اسم زیبا برای تصویر زیر بزار"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}"
                    }
                }
            ]
        }
    ]
)

print(response['choices'][0]['message']['content'])
# Out:
# "رویارویی با هیولای شب"

# %%
from litellm import completion
import base64

def encode_image(image_path):
    with open(image_path, "rb") as image_file:
        return base64.b64encode(image_file.read()).decode('utf-8')

image_path = "image.webp"
base64_image = encode_image(image_path)

response = completion(
    model="ollama/gemma3:4b", 
    messages=[
        {
            "role": "user",
            "content": [
                {"type": "text", "text": "یه اسم زیبا برای تصویر زیر بزار"},
                {
                    "type": "image_url",
                    "image_url": {
                        "url": f"data:image/jpeg;base64,{base64_image}"
                    }
                }
            ]
        }
    ]
)

print(response['choices'][0]['message']['content'])
# Out:
# با توجه به تصویر، پیشنهاد من اسم‌های زیر است:
#
# *   **محک از تاریکی** (متضاد رنگ و درگیری بین نور و تاریک)
# *   **آخرین ایستگاه** (تصویر یک قهرمان در برابر تهدید بزرگ)
# *   **نبرد اژدها** (به‌خاطر وجود موجودی خطرناک در تصویر)
# *   **سایه فرمانده** (تاکید بر شخصیت قهرمان و مبارزه با نیروهای شر)
#
# اگر نظر دیگری دارید یا به دنبال اسم خاصی هستید، خوشحال می‌شوم کمک کنم.
