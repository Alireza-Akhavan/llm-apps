# %% [markdown]
# # How to use **LiteLLM** with Ollama

# %%
import litellm
from litellm import completion
from IPython.display import display, Markdown

def get_completion(prompt, model="ollama/gemma3:4b", temperature=0.2):
    messages = [{"role": "user", "content": prompt}]
    
    response = completion(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    
    return response.choices[0].message.content

def ltr_print(text):
    display(Markdown(text))
    
def rtl_print(text):
    display(Markdown(f'<span style="direction: rtl; display: block; text-align: right;">{text}</span>'))

# %%
prompt = f"""
what is the capital of Iran?
"""
response = get_completion(prompt)
ltr_print(response)
# Out:
# The capital of Iran is **Tehran**.
#
# Do you want to know anything else about Tehran or Iran in general?

# %%
prompt = f"""
پایتخت ایران کجاست؟
"""
response = get_completion(prompt)
rtl_print(response)
# Out:
# <span style="direction: rtl; display: block; text-align: right;">پایتخت ایران شهر **تهران** است.</span>

# %%
import dotenv
dotenv.load_dotenv()
# Out:
# True

# %%
get_completion(prompt, model='openai/gpt-5.2')
# Out:
# 'پایتخت ایران **تهران** است.'
