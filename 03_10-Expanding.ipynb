# %% [markdown]
# # Expanding

# %%
import litellm
from litellm import completion
from IPython.display import display, Markdown

def get_completion(prompt, model="ollama/gemma4:e4b", temperature=0.2):
    messages = [{"role": "user", "content": prompt}]
    
    response = completion(
        model=model,
        messages=messages,
        temperature=temperature,
    )
    
    return response.choices[0].message.content

def ltr_print(text):
    display(Markdown(text))
    
def rtl_print(text):
    text_with_br = text.replace('\n', '<br>')
    display(Markdown(f'<span style="direction: rtl; display: block; text-align: right;">{text_with_br}</span>'))

# %% [markdown]
# ## Customize the automated reply to a customer email

# %%
# given the sentiment from the lesson on "inferring",
# and the original customer message, customize the email
sentiment = "negative"

review ="""
بنابراین، آنها هنوز هم سیستم 17 قطعه‌ای را در فروش فصلی با تخفیف حدود 49 دلار در ماه نوامبر داشتند،
 تقریباً نصف قیمت، اما به دلیل افزایش قیمتی، در هفته دوم دسامبر قیمت ها  بین 70 تا 89 دلار برای همان سیستم افزایش یافت.
 و همچنین سیستم 11 قطعه‌ای نیز در قیمت حدود 10 دلار افزایش یافته است. 
خبب ممکنه این به نظر مشکلی نباشه، اما اگر به پایه نگاه کنید، قسمتی که تیغه در آن قفل می‌شود،
 به نظر نمی‌رسد بهتر از نسخه‌های قبلی چند سال پیش شده باشد!
 من قصد دارم با این دستگاه بسیار ملایم باشم (مثال: من اول اشیای سخت مانند لوبیا، یخ و برنج را در مخلوط کن ابتدا خرد می‌کنم، 
سپس آنها را در اندازه سرویسی که می‌خواهم در مخلوط کن خرد می‌کنم، 
سپس به تیغه های تخمیر کننده برای تهیه آردی با دانه های کوچکتر و با تیغه های برش متقاطع برای تهیه اسموتی استفاده می‌کنم، 
سپس اگر نیاز به آنها با دانه های کوچکتر / کمتر پالپی داشته باشم از تیغه صاف استفاده می‌کنم).
 نکته ویژه در هنگام تهیه اسموتی، میوه ها و سبزیجات را به صورت خیلی ریز خرد کرده و یخ بزنید 
(اگر از اسفناج استفاده می‌کنید، آن را به طور خفیف پخته و نرم کنید، سپس آن را تا زمان استفاده یخ بزنید - و اگر سوربه تهیه می‌کنید، از یک فرآورده غذایی کوچک تا متوسط ​​استفاده کنید)، 
به این شکل می‌توانید از اضافه کردن بسیاری از یخ در اسموتی خود جلوگیری کنید.
 بعد از حدود یک سال، موتور صدای عجیبی می‌دهد. 
من با خدمات مشتری تماس گرفتم اما گارانتی قبلاً منقضی شده بود، 
بنابراین مجبور به خرید دوباره بودم. 
اطلاعات بیشتر: کیفیت کلی این نوع محصولات کاهش یافته است،
 بنابراین آنها به شناخت برند و وفاداری مشتریان برای حفظ فروش شان حساب می‌کنند.
 من آن را در حدود دو روز دریافت کردم.
"""

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service. 
Write in a concise and professional tone.
Sign the email as `دستیار هوشمند`.
The email must be in Persian.
Make sure to use specific details from the review.
Our phone number is 021-7777
our email is: Akhavan@support.com
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt)
rtl_print(response)
# Out:
# <span style="direction: rtl; display: block; text-align: right;">**موضوع:** در مورد بازخورد ارزشمند شما<br><br>**متن ایمیل:**<br><br>با سلام،<br><br>از اینکه وقت گذاشتید و بازخورد خود را با ما به اشتراک گذاشتید، سپاسگزاریم. ما متأسفیم که تجربه شما با محصول ما، به خصوص در مورد صدای عجیب موتور پس از حدود یک سال استفاده، رضایت‌بخش نبوده است.<br><br>ما نگرانی‌های شما در مورد کاهش کیفیت کلی محصولات و همچنین تغییرات قیمت‌ها را کاملاً درک می‌کنیم و به این نکته توجه ویژه‌ای داریم. کیفیت و رضایت مشتریان برای ما در اولویت قرار دارد.<br><br>لطفاً برای پیگیری دقیق‌تر مشکل موتور و هرگونه نیاز به پشتیبانی، مستقیماً با تیم خدمات مشتریان ما تماس بگیرید. ما آماده‌ایم تا با تمام توان به شما کمک کنیم.<br><br>شما می‌توانید از طریق شماره 021-7777 یا ایمیل Akhavan@support.com با ما در ارتباط باشید.<br><br>با احترام،<br>دستیار هوشمند</span>

# %%
review = """ممنون از بابت سایت خوبتون. همه کالاها به موقع دستم رسید و قیمتتون و کیفیت عالیه"""
sentiment = "positive"

prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service. 
Write in a concise and professional tone.
Sign the email as `دستیار هوشمند`.
The email must be in Persian.
Make sure to use specific details from the review.
Our phone number is 021-7777
our email is: Akhavan@support.com
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt)
rtl_print(response)
# Out:
# <span style="direction: rtl; display: block; text-align: right;">**موضوع:** سپاس از بازخورد ارزشمند شما<br><br>**متن ایمیل:**<br><br>با سلام،<br><br>از اینکه وقت گذاشتید و بازخورد بسیار مثبتی در مورد سایت و محصولات ما ارائه دادید، صمیمانه سپاسگزاریم.<br><br>شنیدن اینکه کالاها به موقع به دست شما رسید و از کیفیت و قیمت محصولاتمان راضی هستید، باعث افتخار ماست. تلاش ما برای ارائه بهترین خدمات و محصولات، همواره در اولویت ما قرار دارد.<br><br>امیدواریم در آینده نیز خریدتان را از ما انجام دهید.<br><br>با احترام،<br>دستیار هوشمند<br><br>**اطلاعات تماس:**<br>تلفن: 021-7777<br>ایمیل: Akhavan@support.com</span>

# %%
# given the sentiment from the lesson on "inferring",
# and the original customer message, customize the email
sentiment = "negative"

# review for a blender
review = f"""
So, they still had the 17 piece system on seasonal \
sale for around $49 in the month of November, about \
half off, but for some reason (call it price gouging) \
around the second week of December the prices all went \
up to about anywhere from between $70-$89 for the same \
system. And the 11 piece system went up around $10 or \
so in price also from the earlier sale price of $29. \
So it looks okay, but if you look at the base, the part \
where the blade locks into place doesn’t look as good \
as in previous editions from a few years ago, but I \
plan to be very gentle with it (example, I crush \
very hard items like beans, ice, rice, etc. in the \
blender first then pulverize them in the serving size \
I want in the blender then switch to the whipping \
blade for a finer flour, and use the cross cutting blade \
first when making smoothies, then use the flat blade \
if I need them finer/less pulpy). Special tip when making \
smoothies, finely cut and freeze the fruits and \
vegetables (if using spinach-lightly stew soften the \
spinach then freeze until ready for use-and if making \
sorbet, use a small to medium sized food processor) \
that you plan to use that way you can avoid adding so \
much ice if at all-when making your smoothie. \
After about a year, the motor was making a funny noise. \
I called customer service but the warranty expired \
already, so I had to buy another one. FYI: The overall \
quality has gone done in these types of products, so \
they are kind of counting on brand recognition and \
consumer loyalty to maintain sales. Got it in about \
two days.
"""

# %%
prompt = f"""
You are a customer service AI assistant.
Your task is to send an email reply to a valued customer.
Given the customer email delimited by ```, \
Generate a reply to thank the customer for their review.
If the sentiment is positive or neutral, thank them for \
their review.
If the sentiment is negative, apologize and suggest that \
they can reach out to customer service. 
Make sure to use specific details from the review.
Write in a concise and professional tone.
Sign the email as `AI customer agent`.
Do not use any email adress or phone.
Customer review: ```{review}```
Review sentiment: {sentiment}
"""
response = get_completion(prompt)
print(response)
# Out:
# Subject: Regarding your recent feedback on our products
#
# Dear valued customer,
#
# Thank you for taking the time to share your detailed feedback. We sincerely apologize for the frustration and disappointment you experienced, particularly regarding the price increases for systems like the 17-piece and 11-piece models, and the concerns about the overall quality.
#
# We are sorry to hear that your motor began making a funny noise after about a year of use. We understand how frustrating it is when a product fails, especially when the warranty has expired. We also acknowledge your comments regarding the perceived decline in quality, such as the base where the blade locks into place.
#
# We take all feedback regarding pricing and product longevity very seriously. For assistance with your motor issue, or to discuss your concerns about the product's current quality and pricing, please reach out to our dedicated customer service team directly. They are best equipped to assist you with next steps.
#
# Thank you again for your loyalty and for bringing these important details to our attention.
#
# Sincerely,
#
# AI customer agent
